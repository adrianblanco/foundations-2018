# %%
import pandas as pd

# %%
# !pip install pandas
# to install it from Jupyter notebooks

# %%
pd.read_csv("school-shootings-data.csv")
# Out:
#      uid nces_school_id                           school_name  \
# 0      1   080480000707                 Columbine High School
# 1      2   220054000422           Scotlandville Middle School
# 2      3   130441001591                  Heritage High School
# 3      4   421899003847              John Bartram High School
# 4      5   250279000225                Dorchester High School
# 5      6   350069000240                  Deming Middle School
# 6      7   401197000559             Fort Gibson Middle School
# 7      8   120153001590                 Ridgewood High School
# 8      9   062460009581        Alicia Reyes Elementary School
# 9     10   170993000748      Duke Ellington Elementary School
# 10    11   280132000190                 Horn Lake High School
# 11    12   402961001555                  Tecumseh High School
# 12    13   260450004135               Buell Elementary School
# 13    14   401521000713                      Hugo High School
# 14    15   040146000077          Carmichael Elementary School
# 15    16   120150002873              Lake Worth Middle School
# 16    17   530723002564                 Dimmitt Middle School
# 17    18   390444101350       Mount Healthy North Junior High
# 18    19   220117000980       Carter G. Woodson Middle School
# 19    20   062927004519                   Hueneme High School
# 20    21   240009000263      Lake Clifton Eastern High School
# 21    22   481623021205       Pearl C. Anderson Middle School
# 22    23   061623002026                   Santana High School
# 23    24        1195358     Bishop Neumann Junior-Senior High
# 24    25   061623002020             Granite Hills High School
# 25    26   180387000637               Lew Wallace High School
# 26    27   220108001296        Monroe City Alternative Center
# 27    28   481854001737                     Ennis High School
# 28    29   062271007751                   Belmont High School
# 29    30   210135000271             Latonia Elementary School
# ..   ...            ...                                   ...
# 191  191   220054000423      Scotlandville Magnet High School
# 192  192   063417005375          North Park Elementary School
# 193  193   220033000252          Moss Bluff Elementary School
# 194  194   010171002162                Greensboro High School
# 195  195   170993001166              Warren Elementary School
# 196  196   390438004430                  Columbus Scioto 6-12
# 197  197   530297000485                   Freeman High School
# 198  198   172505002734                   Mattoon High School
# 199  199   262115008414                    Pattengill Academy
# 200  200   130228000967         Benjamin Banneker High School
# 201  201   060978004178       Rancho Tehama Elementary School
# 202  202   350015000135                     Aztec High School
# 203  203   370192000956        High Point Central High School
# 204  204   482445002740                     Italy High School
# 205  205   220018802340           The NET Charter High School
# 206  206   210381000976           Marshall County High School
# 207  207   010237000942                    Murphy High School
# 208  208   062271012483      Salvador B. Castro Middle School
# 209  209   120018002721  Marjory Stoneman Douglas High School
# 210  210   130162000786                    Dalton High School
# 211  211   010039000141                   Huffman High School
# 212  212   062553003843                   Seaside High School
# 213  213   301854000824                   Big Sky High School
# 214  214   510300001245       Douglass Park Elementary School
# 215  215   240060001224               Great Mills High School
# 216  216   120126001271                    Forest High School
# 217  218   060282009515                  Highland High School
# 218  219   171233001481                     Dixon High School
# 219  220   483927004473                  Santa Fe High School
# 220  221   180765000639        Noblesville West Middle School
#
#      nces_district_id                           district_name        date  \
# 0            804800.0                    Jefferson County R-1   4/20/1999
# 1           2200540.0    East Baton Rouge Parish School Board   4/22/1999
# 2           1304410.0                         Rockdale County   5/20/1999
# 3           4218990.0                    Philadelphia City SD   10/4/1999
# 4           2502790.0                                  Boston   11/3/1999
# 5           3500690.0                   Deming Public Schools  11/19/1999
# 6           4011970.0                             Fort Gibson   12/6/1999
# 7           1201530.0                                   Pasco   1/19/2000
# 202   52.500         9          12   432.0          San Juan County
# 203   94.670         9          12   904.0          Guilford County
# 204   29.210         6          12   173.0             Ellis County
# 205   19.940         9          12     NaN           Orleans Parish
# 206   73.100         9          12   584.0          Marshall County
# 207  120.000         9          12   905.0            Mobile County
# 208   15.830         6           8   309.0       Los Angeles County
# 209  129.000         9          12   710.0           Broward County
# 210  101.700         9          12  1152.0         Whitfield County
# 211   66.000         9          12   775.0         Jefferson County
# 212   52.750         9          12   736.0          Monterey County
# 213   68.290         9          12   405.0          Missoula County
# 214   44.000        KG           6   758.0          Portsmouth City
# 215   86.300         9          12   554.0        St. Mary's County
# 216  101.000         9          12  1048.0            Marion County
# 217  126.420         9          12  1717.0       Los Angeles County
# 218   40.600         9          12   347.0               Lee County
# 219   83.380         9          12   287.0         Galveston County
# 220   64.000         6           8   268.0          Hamilton County
#
#     state_fips  county_fips ulocale
# 0            8         8059    21.0
# 1           22        22033    12.0
# 2           13        13247    21.0
# 3           42        42101    11.0
# 4           25        25025    11.0
# 5           35        35029    33.0
# 6           40        40101    32.0
# 7           12        12101    21.0
# 8            6         6047    13.0
# 9           17        17031    11.0
# 10          28        28033    21.0
# 11          40        40125    32.0
# 12          26        26049    21.0
# 13          40        40023    33.0
# 14           4         4003    13.0
# 15          12        12099    21.0
# 16          53        53033    21.0
# 17          39        39061    21.0
# 18          22        22071    11.0
# 19           6         6111    12.0
# 20          24        24510    11.0
# 21          48        48113    11.0
# 22           6         6073    21.0
# 23          42        42081    13.0
# 24           6         6073    21.0
# 25          18        18089    13.0
# 26          22        22073    13.0
# 27          48        48139    41.0
# 28           6         6037    11.0
# 29          21        21117    21.0
# ..         ...          ...     ...
# 191         22        22033    12.0
# 192          6         6071    12.0
# 193         22        22019    41.0
# 194          1         1065    42.0
# 195         17        17031    11.0
# 196         39        39049    11.0
# 197         53        53063    42.0
# 198         17        17029    32.0
# 199         26        26065    12.0
# 200         13        13121    21.0
# 201          6         6103    43.0
# 202         35        35045    31.0
# 203         37        37081    12.0
# 204         48        48139    42.0
# 205         22        22071    11.0
# 206         21        21157    42.0
# 207          1         1097    12.0
# 208          6         6037    11.0
# 209         12        12011    21.0
# 210         13        13313    13.0
# 211          1         1073    12.0
# 212          6         6053    22.0
# 213         30        30063    13.0
# 214         51        51740    13.0
# 215         24        24037    23.0
# 216         12        12083    22.0
# 217          6         6037    21.0
# 218         17        17103    32.0
# 219         48        48167    22.0
# 220         18        18057    21.0
#
# [221 rows x 50 columns]

# %%
type(pd.read_csv("school-shootings-data.csv"))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("countries.csv")

# %%
# to look at the first five
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.tail()
# Out:
#                 Country Continent  GDP_per_capita  life_expectancy  Population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.tail(10)
# Out:
#                 Country   Continent  GDP_per_capita  life_expectancy  \
# 178       United States  N. America           39758           76.800
# 179             Uruguay  S. America            9092           74.777
# 180          Uzbekistan        Asia            1635           66.999
# 181             Vanuatu     Oceania            3762           67.438
# 182           Venezuela  S. America            9434           72.432
# 183             Vietnam        Asia            1577           73.777
# 184  West Bank and Gaza        Asia            7586           70.929
# 185         Yemen, Rep.        Asia            2217           60.404
# 186              Zambia      Africa            1035           41.802
# 187            Zimbabwe      Africa             745           43.976
#
#      Population
# 178   282496310
# 179     3319066
# 180    24775610
# 181      185074
# 182    24348304
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477

# %%
df.shape
# Out:
# (188, 5)

# %%
df.dtypes
# everytime you have a string it will be listed as an object
# in the future we will have 'categories' as a list
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %% [markdown]
# # The three things you should do when you read in a dataset
# ### 1. look at `.head()` to make sure your data looks kind of right
# ### 2. Look at `.sahpe` how many rows and columnns
# ### 3. Look at `.dtypes` to see the data types of all your columns, and the names of your columns

# %%
df.sort_values(by="Population").head(3)
# sort_values always sorts by ascending order (aka smallest first)
# Out:
#                  Country   Continent  GDP_per_capita  life_expectancy  \
# 64             Greenland  N. America           33204           67.030
# 4    Antigua and Barbuda  N. America           12738           73.544
# 146           Seychelles      Africa           15230           71.771
#
#      Population
# 64        56196
# 4         77656
# 146       78685

# %%
# If we want to sort in descending order (biggest first)
# we have to add ascending=False
df.sort_values(by="Population", ascending=False).head(3)
# Out:
#            Country   Continent  GDP_per_capita  life_expectancy  Population
# 34           China        Asia            3407           72.124  1269116737
# 75           India        Asia            1648           62.129  1053898107
# 178  United States  N. America           39758           76.800   282496310

# %%
df['life_expectancy']
# looks like a dict call
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
# 5      73.822
# 6      71.494
# 7      79.930
# 8      78.330
# 9      66.851
# 10     72.370
# 11     74.497
# 12     65.309
# 13     73.118
# 14     68.990
# 15     77.910
# 16     70.425
# 17     55.261
# 18     60.307
# 19     62.994
# 20     74.882
# 21     50.567
# 22     70.261
# 23     75.927
# 24     71.590
# 25     50.589
# 26     48.251
# 27     62.030
# 28     51.960
# 29     79.410
#         ...
# 158    67.851
# 159    48.689
# 160    79.840
# 161    79.990
# 162    73.316
# 163    76.020
# 164    63.570
# 165    50.010
# 166    70.921
# 167    59.468
# 168    53.585
# 169    70.810
# 170    68.533
# 171    73.159
# 172    70.010
# 173    63.925
# 174    48.126
# 175    67.790
# 176    74.163
# 177    78.040
# 178    76.800
# 179    74.777
# 180    66.999
# 181    67.438
# 182    72.432
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# Name: life_expectancy, Length: 188, dtype: float64

# %%
df['Country']
# Out:
# 0                 Afghanistan
# 1                     Albania
# 2                     Algeria
# 3                      Angola
# 4         Antigua and Barbuda
# 5                   Argentina
# 6                     Armenia
# 7                   Australia
# 8                     Austria
# 9                  Azerbaijan
# 10                    Bahamas
# 11                    Bahrain
# 12                 Bangladesh
# 13                   Barbados
# 14                    Belarus
# 15                    Belgium
# 16                     Belize
# 17                      Benin
# 18                     Bhutan
# 19                    Bolivia
# 20     Bosnia and Herzegovina
# 21                   Botswana
# 22                     Brazil
# 23                     Brunei
# 24                   Bulgaria
# 25               Burkina Faso
# 26                    Burundi
# 27                   Cambodia
# 28                   Cameroon
# 29                     Canada
#                 ...
# 158                  Suriname
# 159                 Swaziland
# 160                    Sweden
# 161               Switzerland
# 162                     Syria
# 163                    Taiwan
# 164                Tajikistan
# 165                  Tanzania
# 166                  Thailand
# 167               Timor-Leste
# 168                      Togo
# 169                     Tonga
# 170       Trinidad and Tobago
# 171                   Tunisia
# 172                    Turkey
# 173              Turkmenistan
# 174                    Uganda
# 175                   Ukraine
# 176      United Arab Emirates
# 177            United Kingdom
# 178             United States
# 179                   Uruguay
# 180                Uzbekistan
# 181                   Vanuatu
# 182                 Venezuela
# 183                   Vietnam
# 184        West Bank and Gaza
# 185               Yemen, Rep.
# 186                    Zambia
# 187                  Zimbabwe
# Name: Country, Length: 188, dtype: object

# %%
# If you pull out a single column, it's called a SERIES

# %%
df['Continent'].value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %% [markdown]
# You can `df['colname']`or `df.colname`, they're the same

# %%
# You can also do:
df.Continent.value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %% [markdown]
# But if you have numeric data...

# %%
# tab to see different options
# <bound method ... go back and put some parenthesis in there
df.life_expectancy.median()
# Out:
# 70.04150000000001

# %%
df.life_expectancy.mean()
# Out:
# 66.50153603526596

# %%
# Is the mean gdp higher or lower than the median GDP?
if df.GDP_per_capita.median() > df.GDP_per_capita.mean():
    print("Median GDP is higher than mean GDP")
else:
    print("Mean GDP is higher than median GDP")
# Out:
# Mean GDP is higher than median GDP

# %%
df.Population.sum()
# Out:
# 6115042358

# %%
df.life_expectancy.max()
# It does not say anything to me
# Out:
# 81.35

# %%
df.sort_values(by='life_expectancy', ascending=False).head(3)
# Out:
#               Country Continent  GDP_per_capita  life_expectancy  Population
# 83              Japan      Asia           28559           81.350   125720310
# 72   Hong Kong, China      Asia           29972           80.361     6783317
# 161       Switzerland    Europe           34386           79.990     7167908

# %%
df.sort_values?

# %%
# Either one of these will work, remember
# df['colname'] is the same as df.colname (...for now)
df['life_expectancy'].describe()
# Out:
# count    188.000000
# mean      66.501536
# std       10.298458
# min       38.123000
# 25%       59.663750
# 50%       70.041500
# 75%       74.134500
# max       81.350000
# Name: life_expectancy, dtype: float64

# %%
df.describe()
# Out:
#        GDP_per_capita  life_expectancy    Population
# count      188.000000       188.000000  1.880000e+02
# mean      9977.558511        66.501536  3.252682e+07
# std      11953.393378        10.298458  1.237952e+08
# min        292.000000        38.123000  5.619600e+04
# 25%       1732.500000        59.663750  2.003170e+06
# 50%       5290.500000        70.041500  6.888970e+06
# 75%      12701.250000        74.134500  2.218517e+07
# max      63924.000000        81.350000  1.269117e+09

# %%
df.life_expectancy.median()
# Out:
# 70.04150000000001

# %% [markdown]
# ## Do analysis based on categories
# Your best friend will be `df.groupby`

# %%
df.groupby('Continent')

# %%
df.groupby('Continent').groups
# Out:
# {'Africa': Int64Index([  2,   3,  17,  21,  25,  26,  28,  30,  31,  32,  36,  37,  38,
#               40,  46,  49,  51,  52,  54,  58,  59,  62,  67,  68,  86,  95,
#               96,  97, 102, 103, 106, 108, 109, 115, 116, 118, 123, 124, 138,
#              142, 144, 146, 147, 152, 153, 154, 157, 159, 165, 168, 171, 174,
#              186, 187],
#             dtype='int64'),
#  'Asia': Int64Index([  0,  11,  12,  18,  23,  27,  34,  72,  75,  76,  77,  78,  80,
#               83,  84,  85,  88,  89,  90,  91,  92,  94, 100, 104, 105, 113,
#              117, 119, 126, 127, 132, 135, 137, 143, 148, 156, 162, 163, 164,
#              166, 167, 172, 173, 176, 180, 183, 184, 185],
#             dtype='int64'),
#  'Europe': Int64Index([  1,   6,   8,   9,  14,  15,  20,  24,  41,  43,  44,  45,  53,
#               56,  57,  60,  61,  63,  73,  74,  79,  81,  93,  98,  99, 101,
#              107, 112, 114, 120, 125, 133, 134, 136, 145, 149, 150, 155, 160,
#              161, 175, 177],
#             dtype='int64'),
#  'N. America': Int64Index([  4,  10,  13,  16,  29,  39,  42,  47,  50,  64,  65,  66,  70,
#               71,  82, 110, 122, 128, 139, 140, 170, 178],
#             dtype='int64'),
#  'Oceania': Int64Index([7, 55, 87, 111, 121, 129, 141, 151, 169, 181], dtype='int64'),
#  'S. America': Int64Index([5, 19, 22, 33, 35, 48, 69, 130, 131, 158, 179, 182], dtype='int64')}

# %%
# We could do either of these, I like the period one better
# but whatever works for you
df.groupby('Continent')['life_expectancy'].median()
df.groupby('Continent').life_expectancy.median()
# Out:
# Continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
df.Population.sum()
# Out:
# 6115042358

# %%
df.groupby('Continent').Population.sum()
# Out:
# Continent
# Africa         809892820
# Asia          3849172861
# Europe         596440013
# N. America     481999240
# Oceania         30272328
# S. America     347265096
# Name: Population, dtype: int64

# %%
# The thing on the left is called the INDEX
# and the thing on the right is called the VALUES

df.groupby('Continent').Population.sum()
# Out:
# Continent
# Africa         809892820
# Asia          3849172861
# Europe         596440013
# N. America     481999240
# Oceania         30272328
# S. America     347265096
# Name: Population, dtype: int64

# %%
# 
# and it doesn't actually have columns to sort by
# we sort this with .sort_values 


df.groupby('Continent').Population.sum().sort_values()
# Out:
# Continent
# Oceania         30272328
# S. America     347265096
# N. America     481999240
# Europe         596440013
# Africa         809892820
# Asia          3849172861
# Name: Population, dtype: int64

# %%
df.groupby('Continent').Population.sum().sort_values(ascending=False)
# Out:
# Continent
# Asia          3849172861
# Africa         809892820
# Europe         596440013
# N. America     481999240
# S. America     347265096
# Oceania         30272328
# Name: Population, dtype: int64

# %%
df.Continent.value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %%
df.Continent.value_counts?

# %%
df.Continent.value_counts(normalize=True)
# Out:
# Africa        0.287234
# Asia          0.255319
# Europe        0.223404
# N. America    0.117021
# S. America    0.063830
# Oceania       0.053191
# Name: Continent, dtype: float64

# %%
df.Continent.value_counts(normalize=True) * 100
# There is no need to do a for loop
# Out:
# Africa        28.723404
# Asia          25.531915
# Europe        22.340426
# N. America    11.702128
# S. America     6.382979
# Oceania        5.319149
# Name: Continent, dtype: float64

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %%
df.GDP_per_capita
# Out:
# 0        663
# 1       4195
# 2       5098
# 3       2446
# 4      12738
# 5      10571
# 6       2114
# 7      29241
# 8      32008
# 9       2533
# 10     22728
# 11     22015
# 12      1075
# 13     14982
# 14      5936
# 15     29940
# 16      6545
# 17      1307
# 18      2922
# 19      3394
# 20      5733
# 21     10107
# 22      8056
# 23     48020
# 24      6907
# 25      1001
# 26       443
# 27       982
# 28      1803
# 29     32448
#        ...
# 158     5677
# 159     4021
# 160    28640
# 161    34386
# 162     3935
# 163    23525
# 164     1001
# 165      826
# 166     5578
# 167     2743
# 168      890
# 169     4886
# 170    10496
# 171     5480
# 172     6803
# 173     3289
# 174      881
# 175     3700
# 176    30012
# 177    28644
# 178    39758
# 179     9092
# 180     1635
# 181     3762
# 182     9434
# 183     1577
# 184     7586
# 185     2217
# 186     1035
# 187      745
# Name: GDP_per_capita, Length: 188, dtype: int64

# %%
df.GDP_per_capita * df.Population
# Out:
# 0         15153728226
# 1         12886435920
# 2        155661450046
# 3         34063908358
# 4           989182128
# 5        390394524839
# 6          6502871172
# 7        560384787591
# 8        256214821696
# 9         20544461359
# 10         6765011928
# 11        14049818895
# 12       139311695625
# 13         4007849802
# 14        59703160160
# 15       304659978960
# 16         1639601040
# 17         8518777670
# 18         1669227564
# 19        28194799712
# 20        21175970634
# 21        17767347975
# 22      1405170917672
# 23        15704268720
# 24        55298533306
# 25        12306306012
# 26         2823835721
# 27        12222903918
# 28        28267919007
# 29       995094659520
#             ...
# 158        2650284742
# 159        4277668472
# 160      253754781920
# 161      246475684488
# 162       62914881290
# 163      521855075000
# 164        6178979807
# 165       28115520986
# 166      352278751762
# 167        2276934127
# 168        4266218560
# 169         478510410
# 170       13561440768
# 171       51819521160
# 172      432860345186
# 173       14805167091
# 174       21331758720
# 175      180899630400
# 176       91041131892
# 177     1686390207348
# 178    11231488292980
# 179       30176948072
# 180       40508122350
# 181         696248388
# 182      229701899936
# 183      124201381770
# 184       24264276160
# 185       39292303362
# 186       10558616670
# 187        9319560365
# Length: 188, dtype: int64

# %%
# This does not work
# df.GDP = df.GDP_per_capita * df.Population
df['GDP'] = df.GDP_per_capita * df.Population
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population           GDP
# 0    22856302   15153728226
# 1     3071856   12886435920
# 2    30533827  155661450046
# 3    13926373   34063908358
# 4       77656     989182128

# %%
df.Continent == 'Africa'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25      True
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 158    False
# 159     True
# 160    False
# 161    False
# 162    False
# 163    False
# 164    False
# 165     True
# 166    False
# 167    False
# 168     True
# 169    False
# 170    False
# 171     True
# 172    False
# 173    False
# 174     True
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186     True
# 187     True
# Name: Continent, Length: 188, dtype: bool

# %%
africa_df = df[df.Continent == 'Africa']
africa_df.head()
# Out:
#          Country Continent  GDP_per_capita  life_expectancy  Population  \
# 2        Algeria    Africa            5098           68.963    30533827
# 3         Angola    Africa            2446           45.234    13926373
# 17         Benin    Africa            1307           55.261     6517810
# 21      Botswana    Africa           10107           50.567     1757925
# 25  Burkina Faso    Africa            1001           50.589    12294012
#
#              GDP
# 2   155661450046
# 3    34063908358
# 17    8518777670
# 21   17767347975
# 25   12306306012

# %%
# Multiple conditions
# Why this look so bad
# help
# no can't sorry just suffer
df[(df.Continent == 'Africa') & (df.life_expectancy >60)]
# Out:
#                    Country Continent  GDP_per_capita  life_expectancy  \
# 2                  Algeria    Africa            5098           68.963
# 30              Cape Verde    Africa            2291           69.835
# 49                   Egypt    Africa            4629           68.632
# 97                   Libya    Africa            9139           71.872
# 109              Mauritius    Africa            8290           71.202
# 115                Morocco    Africa            3073           68.220
# 142  Sao Tome and Principe    Africa            1320           63.336
# 146             Seychelles    Africa           15230           71.771
# 171                Tunisia    Africa            5480           73.159
#
#      Population           GDP
# 2      30533827  155661450046
# 30       437238    1001712258
# 49     67648419  313144531551
# 97      5231189   47807836271
# 109     1196027    9915063830
# 115    28793236   88481614228
# 142      141010     186133200
# 146       78685    1198372550
# 171     9456117   51819521160

# %%
df.groupby('Continent').life_expectancy.median().plot()

# %%
# If it does not work, import also:
# import matplotlib
# %matplotlib inline

# %%
# Built-in magic commands
# http://ipython.readthedocs.io/en/stable/interactive/magics.html
df.groupby('Continent').life_expectancy.median().plot()

# %%
df.groupby('Continent').life_expectancy.median().plot(kind='barh')

# %%
# To sort it
df.groupby('Continent').life_expectancy.median()
# Out:
# Continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
df.groupby('Continent').life_expectancy.median().sort_values()
# Out:
# Continent
# Africa        52.1025
# Oceania       67.4955
# Asia          70.4275
# N. America    70.5765
# S. America    70.7660
# Europe        75.5800
# Name: life_expectancy, dtype: float64

# %%
df.groupby('Continent').life_expectancy.median().sort_values().plot(kind='barh')

# %%
df.groupby('Continent').life_expectancy.median().sort_values(desc=False).plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-f1f6d93fbc5b> in <module>()
# ----> 1 df.groupby('Continent').life_expectancy.median().sort_values(desc=False).plot(kind='barh')
#
# TypeError: sort_values() got an unexpected keyword argument 'desc'

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population           GDP
# 0    22856302   15153728226
# 1     3071856   12886435920
# 2    30533827  155661450046
# 3    13926373   34063908358
# 4       77656     989182128

# %%
df.plot(x='GDP_per_capita', y='life_expectancy')

# %%
df.plot(x='GDP_per_capita', y='life_expectancy', kind='scatter')
