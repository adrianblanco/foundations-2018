# %% [markdown]
# # Scraping mine data with `.apply`
#
# ## The pages we'll be looking at
#
# If I wanted to read specific information about a specfic mine, it takes a few steps. **Do these steps with your browser before you try any programming.**
#
# 1. Visit the [Mine Data Retrieval System](https://arlweb.msha.gov/drs/drshome.htm)
# 2. Scroll down to **Mine Identification Number (ID) Search**
# 3. Type in a mine ID number, such as `3503598`, click **Search**
# 4. I'm on a page! It lists the MINE NAME and MINE OWNER.
#
# After searching for and finding a mine, I can use this page to **find reports about this mine**. Some of the reports are on accidents, violations, inspections, health samples and more. To get those reports:
#
# 1. Search for a mine (if you haven't already)
# 2. Scroll down and change **Beginning Date** to `1/1/1995` (violation reports begin in 1995, accidents begin in 1983)
# 3. Select the report type of `Violations`
# 4. Click **Get Report**
# 5. I'm on a page! It lists ALL OF THE MINE'S VIOLATIONS.
#
# By changing the report type you're searching for you can find all sorts of different data.

# %% [markdown]
# # Doing this programmatically
#
# ## First, scraping a single page
#
# ### Import your imports

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd

# %% [markdown]
# ### Searching for a mine
#
# Visit the [Mine Data Retrieval System](https://arlweb.msha.gov/drs/drshome.htm) and use Selenium to search for `3503598`
#
# - *TIP: You might need to use the Selenium code to scroll down to the right spot on the page. Or not!*
# - *TIP: Use `.send_keys` to type into the box*
# - *TIP: On pages that never change, you can usually just use XPath if you're feeling lazy*

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://arlweb.msha.gov/drs/drshome.htm")

# %%
# the driver is always the site where you are
# The xptah of the controller search //*[@id="inputdrs"] is the same one as the additional search
# Then, I copied the xpath of the font style inside the td //*[@id="content"]/table[3]/tbody/tr[3]/td[1]/font[1]
controller = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[1]/input[1]')
driver.execute_script("arguments[0].scrollIntoView(true)", controller)
controller.send_keys('3503598')

# %%
search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
search_button.click()

# %% [markdown]
# ### Finding reports
#
# On the "Report Selection Page" (where you should be after you search), use Selenium to...
#
# - Change the **Beginning Date** to `1/1/1995`
# - Select the report type of `Violations`
# - Click **Get Report**
#
# .
#
# - *TIP: Remember, if someone isn't on the page Selenium can't click it!*

# %%
change_date = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]')
change_date.send_keys('1/1/1995')

# %%
report_type = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
report_type.click()

# %%
get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
get_report_button.click()

# %% [markdown]
# ### Saving reports
#
# Save all of the rows of data on that page into a new dataframe. Each column is its own column, **and you also need to save the URL under the 'Standard' column.** Here, I even made you a blank dictionary:
#
# ```python
# data = {}
# data['violator'] = ''
# data['contract_id'] = ''
# data['citation_no'] = ''
# data['case_no'] = ''
# data['date_issues'] = ''
# data['final_order_date'] = ''
# data['section_of_act'] = ''
# data['date_terminated'] = ''
# data['citation'] = ''
# data['s_and_s'] = ''
# data['standard'] = ''
# data['standard_url'] = ''
# data['proposed_penalty'] = ''
# data['citation_status'] = ''
# data['current_penalty'] = ''
# data['amount_paid'] = ''
# ```
#
# - *TIP: Some of those table rows aren't what you want. How can you tell them apart from the good ones? (the previous mine owner ones are okay, I just mean the weird headers)*
# - *TIP: I sense `.find_elements` + a lot of square brackets*
# - *TIP: This is just like scraping a search results page!*
# - *TIP: For the URL, you'll need to find the `a` inside of the cell*
# - *TIP: class name is sadly not going to save your life here, because some of the `tr`s and `td`s have the same class! It's stupid. But there's a trick: CSS selectors! Something like `div#container` finds a `div` with the id of `container`, while `span.important` finds a `span` with the class of `important`. It should be helpful! And use `.find_elements_by_` + tab to see what the command is*

# %%
reports = []

rows = driver.find_elements_by_css_selector('tr.drsviols')

for row in rows:
        
    data = {}
    data['violator'] = row.find_elements_by_tag_name('td')[0].text
    data['contract_id'] = row.find_elements_by_tag_name('td')[1].text
    data['citation_no'] = row.find_elements_by_tag_name('td')[2].text
    data['case_no'] = row.find_elements_by_tag_name('td')[3].text
    data['date_issues'] = row.find_elements_by_tag_name('td')[4].text
    data['final_order_date'] = row.find_elements_by_tag_name('td')[5].text
    data['section_of_act'] = row.find_elements_by_tag_name('td')[6].text
    data['date_terminated'] = row.find_elements_by_tag_name('td')[7].text
    data['citation'] = row.find_elements_by_tag_name('td')[8].text
    data['s_and_s'] = row.find_elements_by_tag_name('td')[9].text
    data['standard'] = row.find_elements_by_tag_name('td')[10].text
    data['standard_url'] = row.find_elements_by_tag_name('td')[10].find_element_by_tag_name('a').get_attribute('href')
    data['proposed_penalty'] = row.find_elements_by_tag_name('td')[11].text
    data['citation_status'] = row.find_elements_by_tag_name('td')[12].text
    data['current_penalty'] = row.find_elements_by_tag_name('td')[13].text
    data['amount_paid'] = row.find_elements_by_tag_name('td')[14].text

    reports.append(data)

# %% [markdown]
# rows  = driver.find_elements_by_css_selector('tr.drsviols')
# reports = []
#
# for row in rows:
#
#     cells = row.find_elements_by_tag_name('td')
#
#     data = {}
#     data['violator'] = row.find_elements_by_tag_name('td')[0].text
#     data['contract_id'] = cells[1].text
#     data['citation_no'] = cells[2].text
#     data['case_no'] = cells[3].text
#     data['date_issues'] = cells[4].text
#     data['final_order_date'] = cells[5].text
#     data['section_of_act'] = cells[6].text
#     data['date_terminated'] = cells[7].text
#     data['citation'] = cells[8].text
#     data['s_and_s'] = cells[9].text
#     data['standard'] = cells[10].text
#     data['standard_url'] = cells[10].find_element_by_tag_name('a').get_attribute('href')
#     data['proposed_penalty'] = cells[11].text
#     data['citation_status'] = cells[12].text
#     data['current_penalty'] = cells[13].text
#     data['amount_paid'] = cells[14].text
#
#
#     reports.append(data)

# %%
df_violations = pd.DataFrame(reports)
df_violations
# Out:
#    amount_paid    case_no citation citation_no citation_status contract_id  \
# 0      116.00   000440809        C   8992368            Closed
# 1      116.00   000435717        C   8992214            Closed
# 2      100.00   000398910        C   8872461            Closed
# 3      100.00   000398910        C   8872462            Closed
# 4      100.00   000383840        C   8790965            Closed
# 5      100.00   000383840        C   8790964            Closed
# 6      100.00   000383840        C   8790962            Closed
# 7      873.00   000383840        C   8790963            Closed
# 8      100.00   000345066        C   8694458            Closed
# 9      100.00   000345066        C   8694457            Closed
# 10     100.00   000345066        C   8694455            Closed
# 11     100.00   000345066        C   8694450            Closed
# 12     243.00   000345066        C   8694454            Closed
# 13     100.00   000345066        C   8694452            Closed
# 14     100.00   000347758        C   8694451            Closed
# 15     100.00   000345066        C   8694453            Closed
# 16     100.00   000345066        C   8694456            Closed
# 17     100.00   000291331        C   8599788            Closed
# 18     243.00   000297041        C   8599789            Closed
# 19     100.00   000291331        C   8599787            Closed
# 20     100.00   000269626        C   8599107            Closed
# 21     100.00   000239613        C   8599026            Closed
# 22     100.00   000239613        C   8599025            Closed
# 23     117.00   000220925        C   6398905            Closed
# 24     100.00   000210055        C   6338508            Closed
# 25     100.00   000210055        C   6338510            Closed
# 26     100.00   000210055        C   6338511            Closed
# 27     100.00   000210055        C   6338512            Closed
# 28     100.00   000210055        C   6338507            Closed
# 29     100.00   000210055        C   6338509            Closed
# 30     100.00   000180614        C   6479618            Closed
# 31     100.00   000180614        C   6479620            Closed
# 32     100.00   000180614        C   6479617            Closed
# 33     263.00   000180614        C   6479612            Closed
# 34     100.00   000180614        C   6479615            Closed
# 35     100.00   000180614        C   6479616            Closed
# 36     100.00   000180614        C   6479619            Closed
# 37     100.00   000180614        C   6479614            Closed
# 38     100.00   000180614        C   6479613            Closed
# 39     100.00   000152001        C   6430326            Closed
# 40     100.00   000152001        C   6430325            Closed
# 41     100.00   000121048        C   6342893            Closed
# 42     100.00   000121048        C   6342894            Closed
# 43     100.00   000121048        C   6342895            Closed
# 44     100.00   000121048        C   6342892            Closed
# 45      60.00   000086543        C   6383437            Closed
# 46      60.00   000086543        C   6383438            Closed
# 47      60.00   000051247        C   6368407            Closed
# 48      99.00   000044260        C   6368406            Closed
#
#    current_penalty date_issues date_terminated final_order_date  \
# 0          116.00     5/2/2017        5/2/2017       7/23/2017
# 1          116.00     2/7/2017        2/8/2017       5/21/2017
# 2          100.00   10/21/2015      10/27/2015       1/13/2016
# 3          100.00   10/21/2015      10/27/2015       1/13/2016
# 4          100.00    4/15/2015       4/15/2015       7/17/2015
# 5          100.00    4/13/2015       4/15/2015       7/17/2015
# 6          100.00    4/10/2015       4/10/2015       7/17/2015
# 7          873.00    4/10/2015       4/13/2015       7/17/2015
# 8          100.00    1/29/2014       1/29/2014       4/12/2014
# 9          100.00    1/29/2014       1/29/2014       4/12/2014
# 10         100.00    1/28/2014       1/29/2014       4/12/2014
# 11         100.00    1/28/2014       1/29/2014       4/12/2014
# 12         243.00    1/28/2014       1/29/2014       4/12/2014
# 13         100.00    1/28/2014       1/29/2014       4/12/2014
# 14         100.00    1/28/2014       1/29/2014       5/14/2014
# 15         100.00    1/28/2014       1/29/2014       4/12/2014
# 16         100.00    1/28/2014       1/29/2014       4/12/2014
# 17         100.00     5/1/2012        5/7/2012       7/13/2012
# 18         243.00     5/1/2012        5/7/2012       9/13/2012
# 19         100.00     5/1/2012        5/7/2012       7/13/2012
# 20         100.00     9/7/2011       9/19/2011      11/18/2011
# 21         100.00    10/7/2010       10/7/2010        1/5/2011
# 22         100.00    10/7/2010       10/7/2010        1/5/2011
# 23         117.00    4/20/2010        6/8/2010        7/9/2010
# 24         100.00   12/29/2009      12/30/2009       1/10/2013
# 25         100.00   12/29/2009      12/30/2009       1/10/2013
# 26         100.00   12/29/2009       1/11/2010       1/10/2013
# 27         100.00   12/29/2009      12/29/2009       1/10/2013
# 28         100.00   12/29/2009       1/11/2010       1/10/2013
# 29         100.00   12/29/2009       1/11/2010       1/10/2013
# 30         100.00    2/26/2009        3/4/2009       5/22/2010
# 31         100.00    2/26/2009        3/4/2009        5/8/2009
# 32         100.00    2/26/2009        3/4/2009        5/8/2009
# 33         263.00    2/26/2009        3/4/2009       5/22/2010
# 34         100.00    2/26/2009        3/4/2009       5/22/2010
# 35         100.00    2/26/2009        3/4/2009       5/22/2010
# 36         100.00    2/26/2009       2/26/2009       5/22/2010
# 37         100.00    2/26/2009        3/4/2009       5/22/2010
# 38         100.00    2/26/2009       2/26/2009       5/22/2010
# 39         100.00     4/2/2008        4/3/2008       7/10/2008
# 40         100.00     4/2/2008        4/3/2008       7/10/2008
# 41         100.00    5/23/2007       5/24/2007       8/17/2007
# 42         100.00    5/23/2007       5/24/2007       8/17/2007
# 43         100.00    5/23/2007       5/24/2007       8/17/2007
# 44         100.00    5/23/2007       5/24/2007       8/17/2007
# 45          60.00     3/1/2006        3/2/2006       6/16/2006
# 46          60.00     3/1/2006        3/2/2006       6/16/2006
# 47          60.00   10/27/2004       1/21/2005       7/23/2005
# 48          99.00   10/25/2004      10/27/2004       1/12/2005
#
#    proposed_penalty s_and_s section_of_act        standard  \
# 0            116.00       N         104(a)     56.14107(a)
# 1            116.00       N         104(a)     56.14107(a)
# 2            100.00       N         104(a)        56.12004
# 3            100.00       N         104(a)     56.14107(a)
# 4            100.00       N         104(a)        56.13015
# 5            100.00       N         104(a)         56.4101
# 6            100.00       N         104(a)     56.14107(a)
# 7            873.00       Y         104(a)        56.15020
# 8            100.00       N         104(a)        56.12018
# 9            100.00       N         104(a)        56.12004
# 10           100.00       N         104(a)        56.12004
# 11           100.00       N         104(a)     56.14132(a)
# 12           243.00       Y         104(a)        56.12032
# 13           100.00       N         104(a)     56.14132(a)
# 14           100.00       N         104(a)     56.14100(b)
# 15           100.00       N         104(a)   56.4201(a)(1)
# 16           100.00       N         104(a)  56.14132(b)(1)
# 17           100.00       N         104(a)        56.12004
# 18           243.00       Y         104(a)  56.14101(a)(2)
# 19           100.00       N         104(a)        56.14108
# 20           100.00       N         104(a)        50.30(a)
# 21           100.00       N         104(a)        56.12004
# 22           100.00       N         104(a)        56.12004
# 23           117.00       Y         104(a)        56.11001
# 24           100.00       N         104(a)        56.11002
# 25           100.00       N         104(a)     56.14107(a)
# 26           100.00       N         104(a)     56.14107(a)
# 27           100.00       N         104(a)        56.12004
# 28           100.00       N         104(a)     56.14107(a)
# 29           100.00       N         104(a)     56.14107(a)
# 30           100.00       N         104(a)     56.14130(i)
# 31           100.00       N         104(a)        56.12028
# 32           100.00       N         104(a)   56.4201(a)(2)
# 33           263.00       Y         104(a)      56.9200(d)
# 34           100.00       N         104(a)     56.14100(b)
# 35           100.00       N         104(a)     56.14103(b)
# 36           100.00       N         104(a)     56.14100(a)
# 37           100.00       N         104(a)     56.14100(d)
# 38           100.00       Y         104(a)         56.3200
# 39           100.00       N         104(a)     56.14100(b)
# 40           100.00       N         104(a)  56.14112(a)(1)
# 41           100.00       N         104(a)     56.14100(b)
# 42           100.00       N         104(a)     56.14132(a)
# 43           100.00       N         104(a)     56.14107(a)
# 44           100.00       N         104(a)     56.14100(b)
# 45            60.00       N         104(a)     56.14107(a)
# 46            60.00       N         104(a)        56.11002
# 47            60.00       N         104(a)          62.120
# 48            99.00       Y         104(a)     56.14131(a)
#
#                                          standard_url             violator
# 0   http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...  Newberg Rock & Dirt
# 1   http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...  Newberg Rock & Dirt
# 2   http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 3   http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 4   http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 5   http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 6   http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 7   http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 8   http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 9   http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 10  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 11  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 12  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 13  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 14  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 15  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 16  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...  Newberg Rock & Dirt
# 17  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...  Newberg Rock & Dirt
# 18  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...  Newberg Rock & Dirt
# 19  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...  Newberg Rock & Dirt
# 20  http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-...  Newberg Rock & Dirt
# 21  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...  Newberg Rock & Dirt
# 22  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...  Newberg Rock & Dirt
# 23  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...  Newberg Rock & Dirt
# 24  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 25  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 26  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 27  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 28  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 29  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 30  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 31  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 32  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 33  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 34  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 35  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 36  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 37  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 38  http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-...  Newberg Rock & Dirt
# 39  http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-...  Newberg Rock & Dirt
# 40  http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-...  Newberg Rock & Dirt
# 41  http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-...  Newberg Rock & Dirt
# 42  http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-...  Newberg Rock & Dirt
# 43  http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-...  Newberg Rock & Dirt
# 44  http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-...  Newberg Rock & Dirt
# 45  http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-...  Newberg Rock & Dirt
# 46  http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-...  Newberg Rock & Dirt
# 47  http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-...  Newberg Rock & Dirt
# 48  http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-...  Newberg Rock & Dirt

# %% [markdown]
# ### Saving that data
#
# Save the dataframe to a CSV file called `3503598-violations.csv` (that's the TDLR code)

# %%
df_violations.to_csv("3503598-violations.csv", index=False)

# %% [markdown]
# ## Put that all in ONE cell that runs correctly
#
# The **entire process**, from searching to saving as a CSV

# %%
# After trying so many times, I included all the code needed to scrape the site in one cell
# as I went mad going back and running several times the same snippets of code

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd

driver = webdriver.Chrome()

driver.get("https://arlweb.msha.gov/drs/drshome.htm")

controller = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[1]/input[1]')
driver.execute_script("arguments[0].scrollIntoView(true)", controller)
controller.send_keys('3503598')

search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
search_button.click()

change_date = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]')
change_date.send_keys('1/1/1995')

report_type = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
report_type.click()

get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
get_report_button.click()

reports = []

rows = driver.find_elements_by_css_selector('tr.drsviols')

for row in rows:
        
    data = {}
    data['violator'] = row.find_elements_by_tag_name('td')[0].text
    data['contract_id'] = row.find_elements_by_tag_name('td')[1].text
    data['citation_no'] = row.find_elements_by_tag_name('td')[2].text
    data['case_no'] = row.find_elements_by_tag_name('td')[3].text
    data['date_issues'] = row.find_elements_by_tag_name('td')[4].text
    data['final_order_date'] = row.find_elements_by_tag_name('td')[5].text
    data['section_of_act'] = row.find_elements_by_tag_name('td')[6].text
    data['date_terminated'] = row.find_elements_by_tag_name('td')[7].text
    data['citation'] = row.find_elements_by_tag_name('td')[8].text
    data['s_and_s'] = row.find_elements_by_tag_name('td')[9].text
    data['standard'] = row.find_elements_by_tag_name('td')[10].text
    data['standard_url'] = row.find_elements_by_tag_name('td')[10].find_element_by_tag_name('a').get_attribute('href')
    data['proposed_penalty'] = row.find_elements_by_tag_name('td')[11].text
    data['citation_status'] = row.find_elements_by_tag_name('td')[12].text
    data['current_penalty'] = row.find_elements_by_tag_name('td')[13].text
    data['amount_paid'] = row.find_elements_by_tag_name('td')[14].text

    reports.append(data)
    
df_violations = pd.DataFrame(reports)
df_violations.head()

df_violations.to_csv("3503598-violations.csv", index=False)

# %%
# Checking everything is fine

df = pd.read_csv("3503598-violations.csv")
df.head()
# Out:
#    amount_paid  case_no citation  citation_no citation_status contract_id  \
# 0        116.0   440809        C      8992368          Closed
# 1        116.0   435717        C      8992214          Closed
# 2        100.0   398910        C      8872462          Closed
# 3        100.0   398910        C      8872461          Closed
# 4        100.0   383840        C      8790965          Closed
#
#    current_penalty date_issues date_terminated final_order_date  \
# 0            116.0    5/2/2017        5/2/2017       7/23/2017
# 1            116.0    2/7/2017        2/8/2017       5/21/2017
# 2            100.0  10/21/2015      10/27/2015       1/13/2016
# 3            100.0  10/21/2015      10/27/2015       1/13/2016
# 4            100.0   4/15/2015       4/15/2015       7/17/2015
#
#    proposed_penalty s_and_s section_of_act     standard  \
# 0             116.0       N         104(a)  56.14107(a)
# 1             116.0       N         104(a)  56.14107(a)
# 2             100.0       N         104(a)  56.14107(a)
# 3             100.0       N         104(a)     56.12004
# 4             100.0       N         104(a)     56.13015
#
#                                         standard_url             violator
# 0  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...  Newberg Rock & Dirt
# 1  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...  Newberg Rock & Dirt
# 2  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 3  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 4  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt

# %% [markdown]
# # Using .apply to find data about SEVERAL mines
#
# The file `mines-subset.csv` has a list of mine IDs. We're going to scrape the operator's name for each of those mines.
#
# ### Open up `mines-subset.csv` and save it into a dataframe

# %%
df = pd.read_csv("mines-subset.csv")

# %%
df.head()
# Out:
#         id
# 0  4104757
# 1   801306
# 2  3609931

# %% [markdown]
# ### Open up `mines-subset.csv` in a text editor, then look at your dataframe. Is something different about them? If so, make them match.
#
# - *TIP: You can zero fill if you want, but another option is that when reading in a CSV, `dtype='str'` will force everything to be a string*

# %%
df = pd.read_csv("mines-subset.csv", dtype='str')
df.head()
# Out:
#         id
# 0  4104757
# 1  0801306
# 2  3609931

# %% [markdown]
# ### Convert your one-cell scraper into a function, and use it on each row of our dataset
#
# - *TIP: You'll be using `.apply`*
# - *TIP: You won't be joining this back into your dataframe, so you don't need to `return` anything or `join` or any of that.*
# - *TIP: Be careful of your **other variable names** - if you're calling the thing you're sending your function `row`, you can't use it anywhere else (like in your loop)*
# - *TIP: **BE CAREFUL WHAT YOU NAME YOUR DATAFRAMES.** If you name the citations dataframe `df` it can overwrite your mine ID `df`*
# - *TIP: You'll be saving a dataframe each time*
# - *TIP: Be sure you change everything that refers to the mine ID to refer to the current row's ID instead of `3503598`*
# - *TIP: BE SURE TO CHANGE EVERYTHING THAT REFERS TO THE MINE ID*
# - *TIP: EVERYTHING, EVERYTHING, EVERYTHING! Look at the end of your function! Maybe I'm overreacting, I don't know.*
# - *TIP: If you hit an error about list index out of range, see what line it's happening on and go look at the page. What's different about this page than the previous ones? (answer: the last three columns!) If you assign those columns later using `try`/`except` you should be able to get some data from those rows without throwing it all out. If you can't figure it out, just wrap it all in try/except and give up on those rows*
# - *TIP: Some of the standards might not have links, either, so you might want to wrap that in a `try`/`except`, too!*

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd

def scrape_mines_subset(id):

    driver = webdriver.Chrome()

    driver.get("https://arlweb.msha.gov/drs/drshome.htm")

    controller = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[1]/input[1]')
    driver.execute_script("arguments[0].scrollIntoView(true)", controller)
    controller.send_keys(id)

    search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
    search_button.click()

    change_date = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]')
    change_date.send_keys('1/1/1995')

    report_type = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
    report_type.click()

    get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
    get_report_button.click()

    reports = []

    rows = driver.find_elements_by_css_selector('tr.drsviols')

    for row in rows:
        
        data = {}
        data['violator'] = row.find_elements_by_tag_name('td')[0].text
        data['contract_id'] = row.find_elements_by_tag_name('td')[1].text
        data['citation_no'] = row.find_elements_by_tag_name('td')[2].text
        data['case_no'] = row.find_elements_by_tag_name('td')[3].text
        data['date_issues'] = row.find_elements_by_tag_name('td')[4].text
        data['final_order_date'] = row.find_elements_by_tag_name('td')[5].text
        data['section_of_act'] = row.find_elements_by_tag_name('td')[6].text
        data['date_terminated'] = row.find_elements_by_tag_name('td')[7].text
        data['citation'] = row.find_elements_by_tag_name('td')[8].text
        data['s_and_s'] = row.find_elements_by_tag_name('td')[9].text
        
        try: 
            
            data['standard'] = row.find_elements_by_tag_name('td')[10].text
            data['standard_url'] = row.find_elements_by_tag_name('td')[10].find_element_by_tag_name('a').get_attribute('href')
            data['proposed_penalty'] = row.find_elements_by_tag_name('td')[11].text
            data['citation_status'] = row.find_elements_by_tag_name('td')[12].text
            data['current_penalty'] = row.find_elements_by_tag_name('td')[13].text
            data['amount_paid'] = row.find_elements_by_tag_name('td')[14].text
        
        except:

            data['standard'] = 'N/A' # Not assesed or Non-Assessable or N/A
            data['standard_url'] = 'N/A'
            data['proposed_penalty'] = 'N/A'
            data['citation_status'] = 'N/A'
            data['current_penalty'] = 'N/A'
            data['amount_paid'] = 'N/A'
            
        reports.append(data)
    
    df_violations = pd.DataFrame(reports)
    df_violations.head()
    
    df_violations.to_csv("{}-violations.csv".format(id), index=False)

# %%
# Don't really understand the Nones but it is working. Ask this!
df['id'].apply(scrape_mines_subset)
# Out:
# 0    None
# 1    None
# 2    None
# Name: id, dtype: object

# %% [markdown]
# # Okay, now do it for ALL of the mines
#
# Open up `mines.csv` using pandas and do the same thing, it will just be for more mines this time.

# %%
df_all_mines = pd.read_csv("mines.csv", dtype='str')
df_all_mines
# Out:
#          id
# 0   3503598
# 1   4801789
# 2   5001797
# 3   4608254
# 4   2103723
# 5   4104757
# 6   0801306
# 7   3901432
# 8   3609624
# 9   3609931
# 10  1519799
# 11  4407296
# 12  4407270
# 13  0203332
# 14  2901986
# 15  4300768
# 16  4300776
# 17  2302283
# 18  2103518

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd

def scrape_mines_subset(id):

    driver = webdriver.Chrome()

    driver.get("https://arlweb.msha.gov/drs/drshome.htm")

    controller = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[1]/input[1]')
    driver.execute_script("arguments[0].scrollIntoView(true)", controller)
    controller.send_keys(id)

    search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
    search_button.click()

    change_date = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]')
    change_date.send_keys('1/1/1995')

    report_type = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
    report_type.click()

    get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
    get_report_button.click()

    reports = []

    rows = driver.find_elements_by_css_selector('tr.drsviols')

    for row in rows:
        
        data = {}
        data['violator'] = row.find_elements_by_tag_name('td')[0].text
        data['contract_id'] = row.find_elements_by_tag_name('td')[1].text
        data['citation_no'] = row.find_elements_by_tag_name('td')[2].text
        data['case_no'] = row.find_elements_by_tag_name('td')[3].text
        data['date_issues'] = row.find_elements_by_tag_name('td')[4].text
        data['final_order_date'] = row.find_elements_by_tag_name('td')[5].text
        data['section_of_act'] = row.find_elements_by_tag_name('td')[6].text
        data['date_terminated'] = row.find_elements_by_tag_name('td')[7].text
        data['citation'] = row.find_elements_by_tag_name('td')[8].text
        data['s_and_s'] = row.find_elements_by_tag_name('td')[9].text
        
        try: 
            
            data['standard'] = row.find_elements_by_tag_name('td')[10].text
            data['standard_url'] = row.find_elements_by_tag_name('td')[10].find_element_by_tag_name('a').get_attribute('href')
            data['proposed_penalty'] = row.find_elements_by_tag_name('td')[11].text
            data['citation_status'] = row.find_elements_by_tag_name('td')[12].text
            data['current_penalty'] = row.find_elements_by_tag_name('td')[13].text
            data['amount_paid'] = row.find_elements_by_tag_name('td')[14].text
        
        except:

            data['standard'] = 'N/A' # Not assesed or Non-Assessable or N/A
            data['standard_url'] = 'N/A'
            data['proposed_penalty'] = 'N/A'
            data['citation_status'] = 'N/A'
            data['current_penalty'] = 'N/A'
            data['amount_paid'] = 'N/A'
            
        reports.append(data)
        
        # I included return to check that everything is going well while scraping.
        # It returns the first row of each .csv
        return pd.Series(data)
    
    df_violations = pd.DataFrame(reports)
    df_violations.head()
    
    df_violations.to_csv("{}-violations.csv".format(id), index=False)

# %%
# Is there a way to scrape it without opening a new browser window each time?
df_all_mines['id'].apply(scrape_mines_subset)
# Out:
#                           violator contract_id citation_no    case_no  \
# 0              Newberg Rock & Dirt               8992368    000440809
# 1   AM Dirtworks & Aggregate Sales               8933510    000426827
# 2                     Dirt Company               8601716    000423303
# 3        Sunshine Reclamation Inc.               8657165    000291395
# 4                  Dirt Doctor Inc               8946233    000422613
# 5                       Dirt Works               8778047    000374480
# 6         Holley Dirt Company, Inc               9421625
# 7   Krueger Brothers Gravel & Dirt               8750964    000361866
# 8                         M R Dirt               8922247    000398559
# 9                   M.R. Dirt Inc.               9317668    000442816
# 10            P B Dirt Movers, Inc               8308898    000450702
# 11                  PB Dirt Movers               8178810    000309181
# 12             PB Dirt Movers, Inc               9870748    000420126
# 13              Prescott Dirt, LLC               8830352
# 14   R D Blankenship Dirt Work LLC               9404249
# 15            SIMPSON DIRTWORX LLC               9365985    000453710
# 16            SIMPSON DIRTWORX LLC               9365981    000453711
# 17      Spry's Dirt & Gravel, Inc.               8968279    000427475
# 18               Vogt Dirt Service               8947442    000456512
#
#    date_issues final_order_date section_of_act date_terminated citation  \
# 0     5/2/2017       7/23/2017          104(a)        5/2/2017        C
# 1    11/1/2016       1/20/2017          104(a)       1/11/2017        C
# 2    10/1/2016      12/16/2016          104(a)      10/28/2016        C
# 3     5/1/2012       7/25/2012          104(a)        5/1/2012        C
# 4    8/31/2016      11/25/2016          104(a)       8/31/2016        C
# 5   10/14/2014       3/27/2015          104(a)       11/4/2014        C
# 6    5/15/2018                          104(a)       5/15/2018        C
# 7    8/12/2014      10/22/2014          104(a)        9/2/2014        C
# 8   10/29/2015       1/10/2016          104(a)      10/29/2015        C
# 9    5/11/2017       8/19/2017          104(a)       5/11/2017        C
# 10   6/29/2017       5/17/2018          104(a)       7/17/2017        C
# 11   9/20/2012       1/18/2013          104(a)       9/28/2012        C
# 12    8/3/2016      10/29/2016          104(a)        8/3/2016        C
# 13   4/27/2015                          104(b)        6/5/2015        O
# 14   5/31/2018                          104(a)       5/31/2018        C
# 15  10/18/2017       1/14/2018          104(a)      10/18/2017        C
# 16  10/18/2017       2/23/2018          104(a)      10/24/2017        C
# 17  11/16/2016        3/6/2017          104(a)      11/16/2016        C
# 18  11/14/2017       2/23/2018          104(a)      11/15/2017        C
#
#    s_and_s     standard                                       standard_url  \
# 0        N  56.14107(a)  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...
# 1        N      56.1000  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 2        N  56.14103(a)  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 3        Y   56.9300(b)  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...
# 4        Y  56.18002(a)  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 5        N     56.18010  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...
# 6        Y          N/A                                                N/A
# 7        N     56.18010  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...
# 8        N     56.12018  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 9        N     50.30(a)  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...
# 10       Y    77.404(a)  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...
# 11       N      77.1000  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...
# 12       N    71.206(a)  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 13     N/A          N/A                                                N/A
# 14       N          N/A                                                N/A
# 15       N      46.9(a)  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...
# 16       N  56.14132(a)  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...
# 17       N      56.4101  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 18       N      56.1000  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...
#
#    proposed_penalty citation_status current_penalty amount_paid
# 0            116.00          Closed         116.00      116.00
# 1            114.00      Delinquent         114.00        0.00
# 2            114.00          Closed         114.00      114.00
# 3            108.00          Closed         108.00      108.00
# 4            124.00      Delinquent         124.00        0.00
# 5            162.00          Closed         162.00      162.00
# 6               N/A             N/A             N/A         N/A
# 7            100.00          Closed         100.00      100.00
# 8            100.00          Closed         100.00      100.00
# 9            116.00          Closed         116.00      116.00
# 10           116.00      Delinquent         116.00        0.00
# 11           100.00          Closed         100.00      100.00
# 12           171.00          Closed         171.00      171.00
# 13              N/A             N/A             N/A         N/A
# 14              N/A             N/A             N/A         N/A
# 15           116.00          Closed         116.00      116.00
# 16           116.00          Closed         116.00      116.00
# 17           114.00          Closed         114.00      114.00
# 18           118.00          Closed         118.00      118.00

# %%
# The .csv files are in the folder!
