# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://arlweb.msha.gov/drs/drshome.htm")

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
contractor_name = driver.find_element_by_name('OperSearch')
contractor_name.send_keys('dirt')

# %%
abandoned_button = driver.find_element_by_name('Abandoned')
abandoned_button.click()

# %%
search_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
search_button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# `.text` will help you here.

# %%
# Index 1 | Index 0 would return the head of the table
first_row = driver.find_elements_by_tag_name('tr')[1]

# %%
# Result
first_row.text
# Out:
# 'Abandoned*\nIndicates Mine is Abandoned and Sealed\n*CM (Coal or Metal Mine/Nonmetal Mine)\nC\nM ...... Coal\n...... Metal/Nonmetal'

# %% [markdown]
# #### As a result the index of the first row element is 1

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# You can use list slicing or an `if` statement to skip the non-data row(s).

# %%
table = driver.find_element_by_xpath('/html/body/div[5]/div/table[3]')
rows = table.find_elements_by_tag_name('tr')

for row in rows[1:]:
    
    # Store the info of each row in a single cell
    # to be able to select by column/variable
    cells = row.find_elements_by_tag_name('td')
    
    operator_name = cells[2].text
    
    print(operator_name)
# Out:
# Newberg Rock & Dirt
# Allied Dirt Moving Company
# AM Dirtworks & Aggregate Sales
# Atlas-Dirty Devil Mining
# Atlas-Dirty Devil Mining
# Babe's Dirt Work
# Bar-Lin Dirt Company
# Barber'S Dirt Pit
# Bender Sand & Dirt
# BERT'S DIRT
# Big D Dirt Service Inc
# Big Red Dirt Farm LLC
# Big River Dirt Pit
# Bob Harris Dirt Contracting
# Bohannon Sand & Dirt
# Bratcher'S Sand & Dirt
# Brewer Dirt Works
# Buck'S Dirt Pit
# C & G Dirt Hauling
# C N C Dirt Movers, Inc.
# Cambridge Dirt Sand and Gravel LLC
# Central Iowa Dirt & Demo LLC
# Crowes Trucking & Dirt Pit Services
# D & H Dirt
# Diez Dirt & Sand Hauling Inc
# Dirt Cheap
# Dirt Company
# Dirt Company
# Dirt Company
# Dirt Con
# Dirt Diggers Inc
# Dirt Doctor Inc
# Dirt Inc
# Dirt Pit
# Dirt Work Specialists LLC
# Dirt Works
# Dirtco Inc
# Dirtman Trucking
# DIRTWORKS, INC.
# Dirtworks, Inc.
# Dirty Coal
# Dorchester Dirt Company Inc
# Douglas Dirt Sand & Gravel Company
# Ell Dirt Works LLC.
# Floyd Smith Dirt Pit
# Gary Kelm Dirt Service
# Gerald Fenger/Rock & Dirt Const
# Gerald Illies Gravel & Dirt Company
# Guidry Sand & Dirt Pit Inc
# Harris Dirt Company Inc
# Hatchet Creek Rock & Dirt LLC
# Holley Dirt Company, Inc
# Iske Dirt Sand & Gravel
# J M Lynn Dirtwork
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jarratt Dirt Work and Paving, Inc.
# JBS DIRT, INC.
# Jones Bros Dirt & Paving Contractors Inc
# Krueger Brothers Gravel & Dirt
# Krueger Dirt Werx, Inc.
# L I P Dirt & Trucking
# Lee'S Dirt Pit Inc
# Little-G-Dirt Pit
# Lone Star Dirt & Paving
# Loyd'S Dirt & Gravel
# M R Dirt
# M.C. Dirt LLC
# M.R. Dirt Inc.
# Maurice Dirt & Sand
# Mc Dirt Industries Inc
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Moss Dirt Company
# Moss Dirt Company
# Muckler Fill Dirt & Top Soil
# Nelson & Sons Dirt Haulers Inc
# Nelson'S Dirt Pit
# Nicholson Dirt Contracting
# Nitty Gritty Dirt LLC
# Northest Louisiana Dirt Contractors
# Orvil Carter Dirt Contractor Inc
# Orvil Carter Dirt Contractor Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc.
# P B Dirt Movers, Inc
# P B Dirt Movers, Inc.
# P.B. Dirtmovers
# PAPA'S DIRT WORKES
# Paydirt Exc Inc
# PB Dirt Movers
# PB Dirt Movers Inc.
# PB Dirt Movers, Inc
# Peveto Dirt Pit
# Phil-Dirt Industries, Inc
# Prescott Dirt, LLC
# R & R Dirtworks
# R D Blankenship Dirt Work LLC
# Reeves Dirt Pit Inc
# River Bottom Dirt
# Roe'S Dirt Pit
# Russell Trest-Dirt Contractor
# S J Stahr Dirt Movers Inc
# Sand & Dirt, Inc
# Sand and Dirt, Inc.
# Sierra Rock & Dirt, Inc.
# Simpson Dirtworx llc
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Slay'S Dirt Hauling
# Southside Dirt Company
# Spry's Dirt & Gravel, Inc.
# Stewart Dirt Pit
# Stewart Dirt Work, Inc.
# Sweat'S Dirt Hauling Inc
# Toler Roe Dirt Pit
# Tres Palacios Dirt, Sand & Gravel
# Vogt Dirt Service
# Watson Dirt Sand & Gravel Pit Inc
# Y B Dirt & Loam
# Yarbrough Dirt Pit Inc
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-9396aca2ffee> in <module>()
#       8     cells = row.find_elements_by_tag_name('td')
#       9
# ---> 10     operator_name = cells[2].text
#      11
#      12     print(operator_name)
#
# IndexError: list index out of range

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
table = driver.find_element_by_xpath('/html/body/div[5]/div/table[3]')
rows = table.find_elements_by_tag_name('tr')

for row in rows[1:]:
    
    # Store the info of each row in a single cell
    # to be able to select by column/variable
    cells = row.find_elements_by_tag_name('td')
    
    operator_id = cells[0].text
    
    print(operator_id)
# Out:
# 3503598
# 0502030
# 4801789
# 4201449
# 4201450
# 1002257
# 1601167
# 4103265
# 1401575
# 1700776
# 1601251
# 0301963
# 1601082
# 3401751
# 1600916
# 3401211
# 0301267
# 1600956
# 2200033
# 0504953
# 3401929
# 1302445
# 1601106
# 3400915
# 1600983
# 4503200
# 3401266
# 3401468
# 5001797
# 4608254
# 1510279
# 2103723
# 0100776
# 4104016
# 2103914
# 4104757
# 0301729
# 0404851
# 2200734
# 5002028
# 1513393
# 3800602
# 3101630
# 3200860
# 3401762
# 2103517
# 2402626
# 2103181
# 1601124
# 1601150
# 4703427
# 0801306
# 2501216
# 3200965
# 2901371
# 2901544
# 2901709
# 4102355
# 4102420
# 4102869
# 4102951
# 4102958
# 4104876
# 3003502
# 4103258
# 3901432
# 2103556
# 1601250
# 1600908
# 1600953
# 4104185
# 2901536
# 3609624
# 3800709
# 3609931
# 1601257
# 0801275
# 1601379
# 1601380
# 1601381
# 1601134
# 1601165
# 3901042
# 1601194
# 4104054
# 4801674
# 2402474
# 1600920
# 4102955
# 4103107
# 1512530
# 1515619
# 1518318
# 4405366
# 4407196
# 1519685
# 1519799
# 4407379
# 4407003
# 2602570
# 2402503
# 4407296
# 1519273
# 4407270
# 4102682
# 0801259
# 0203332
# 0302015
# 2901986
# 1601127
# 4105017
# 1600986
# 4103324
# 4202013
# 0801417
# 0801371
# 2402115
# 4300748
# 4300768
# 4300776
# 0103209
# 1601159
# 2302283
# 4102586
# 4104475
# 3800617
# 1601234
# 4104648
# 2103518
# 1601292
# 4103429
# 4103264
# Total Number of Mines Found:  132

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.

# %%
table = driver.find_element_by_xpath('/html/body/div[5]/div/table[3]')
rows = table.find_elements_by_tag_name('tr')

data = []

# there are 132 results and the first one is the header
for row in rows[1:133]:
    
    rowdict = {}
    
    cells = row.find_elements_by_tag_name('td')
    
    rowdict['operator_id'] = cells[0].text
    rowdict['state'] = cells[1].text
    rowdict['operator_name'] = cells[2].text
    rowdict['mine_name'] = cells[3].text
    rowdict['mine_type'] = cells[4].text
    rowdict['cm'] = cells[5].text
    rowdict['status'] = cells[6].text
    rowdict['commodity'] = cells[7].text
    
    data.append(rowdict)
    
print(data)
# Out:
# [{'operator_id': '3503598', 'state': 'OR ', 'operator_name': 'Newberg Rock & Dirt  ', 'mine_name': 'Newberg Rock & Dirt', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Active ', 'commodity': 'Crushed, Broken Stone NEC '}, {'operator_id': '0502030', 'state': 'CO ', 'operator_name': 'Allied Dirt Moving Company  ', 'mine_name': 'Allied Dirt Moving Co Pit & Plant', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '4801789', 'state': 'ND ', 'operator_name': 'AM Dirtworks & Aggregate Sales  ', 'mine_name': 'AM Dirtworks & Aggregate Sales', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '4201449', 'state': 'UT ', 'operator_name': 'Atlas-Dirty Devil Mining  ', 'mine_name': 'Unit Train Loading Facility', 'mine_type': 'Facility', 'cm': 'C ', 'status': 'Abandoned ', 'commodity': 'Coal (Bituminous) '}, {'operator_id': '4201450', 'state': 'UT ', 'operator_name': 'Atlas-Dirty Devil Mining  ', 'mine_name': 'Blackie Surface Mine & Prep Plant', 'mine_type': 'Surface', 'cm': 'C ', 'status': 'Abandoned ', 'commodity': 'Coal (Bituminous) '}, {'operator_id': '1002257', 'state': 'ID ', 'operator_name': "Babe's Dirt Work  ", 'mine_name': 'Hitt Pit, Inc.', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1601167', 'state': 'LA ', 'operator_name': 'Bar-Lin Dirt Company  ', 'mine_name': 'Bar-Lin Dirt Pit', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '4103265', 'state': 'TX ', 'operator_name': "Barber'S Dirt Pit  ", 'mine_name': "Barber'S Dirt Pit", 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1401575', 'state': 'KS ', 'operator_name': 'Bender Sand & Dirt  ', 'mine_name': 'BENDER SAND & DIRT', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1700776', 'state': 'ME ', 'operator_name': "BERT'S DIRT  ", 'mine_name': "BERT'S DIRT", 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1601251', 'state': 'LA ', 'operator_name': 'Big D Dirt Service Inc  ', 'mine_name': 'Dorothy V Pit', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '0301963', 'state': 'AR ', 'operator_name': 'Big Red Dirt Farm LLC  ', 'mine_name': 'Big Red Dirt Farm', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1601082', 'state': 'LA ', 'operator_name': 'Big River Dirt Pit  ', 'mine_name': 'Big River Dirt Pit', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '3401751', 'state': 'OK ', 'operator_name': 'Bob Harris Dirt Contracting  ', 'mine_name': 'Harris Pit', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1600916', 'state': 'LA ', 'operator_name': 'Bohannon Sand & Dirt  ', 'mine_name': 'BOHANNON SAND & DIRT', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '3401211', 'state': 'OK ', 'operator_name': "Bratcher'S Sand & Dirt  ", 'mine_name': 'Eubanks Pit', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '0301267', 'state': 'AR ', 'operator_name': 'Brewer Dirt Works  ', 'mine_name': 'Brewer Pit', 'mine_type': 'Surface', 'cm': 'M ', 'status': 'Abandoned ', 'commodity': 'Construction Sand and Gravel '}, {'operator_id': '1600956', 'state': 'LA ', 'operator_name': "Buck'S Dirt Pit  ", 'mine_name': "Buck'S Dirt Pit", 'mine_type' ...

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
import pandas as pd

df = pd.DataFrame(data)
df.head(10)
# Out:
#    cm                      commodity                          mine_name  \
# 0  M      Crushed, Broken Stone NEC                 Newberg Rock & Dirt
# 1  M   Construction Sand and Gravel   Allied Dirt Moving Co Pit & Plant
# 2  M   Construction Sand and Gravel      AM Dirtworks & Aggregate Sales
# 3  C              Coal (Bituminous)         Unit Train Loading Facility
# 4  C              Coal (Bituminous)   Blackie Surface Mine & Prep Plant
# 5  M   Construction Sand and Gravel                      Hitt Pit, Inc.
# 6  M   Construction Sand and Gravel                    Bar-Lin Dirt Pit
# 7  M   Construction Sand and Gravel                   Barber'S Dirt Pit
# 8  M   Construction Sand and Gravel                  BENDER SAND & DIRT
# 9  M   Construction Sand and Gravel                         BERT'S DIRT
#
#   mine_type operator_id                     operator_name state         status
# 0   Surface     3503598             Newberg Rock & Dirt     OR         Active
# 1   Surface     0502030      Allied Dirt Moving Company     CO      Abandoned
# 2   Surface     4801789  AM Dirtworks & Aggregate Sales     ND      Abandoned
# 3  Facility     4201449        Atlas-Dirty Devil Mining     UT      Abandoned
# 4   Surface     4201450        Atlas-Dirty Devil Mining     UT      Abandoned
# 5   Surface     1002257                Babe's Dirt Work     ID      Abandoned
# 6   Surface     1601167            Bar-Lin Dirt Company     LA      Abandoned
# 7   Surface     4103265               Barber'S Dirt Pit     TX      Abandoned
# 8   Surface     1401575              Bender Sand & Dirt     KS   Intermittent
# 9   Surface     1700776                     BERT'S DIRT     ME      Abandoned

# %%
df.to_csv("dirt-operators.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
df = pd.read_csv("dirt-operators.csv")

# %%
df.head()
# Out:
#    cm                      commodity                          mine_name  \
# 0  M      Crushed, Broken Stone NEC                 Newberg Rock & Dirt
# 1  M   Construction Sand and Gravel   Allied Dirt Moving Co Pit & Plant
# 2  M   Construction Sand and Gravel      AM Dirtworks & Aggregate Sales
# 3  C              Coal (Bituminous)         Unit Train Loading Facility
# 4  C              Coal (Bituminous)   Blackie Surface Mine & Prep Plant
#
#   mine_type  operator_id                     operator_name state      status
# 0   Surface      3503598             Newberg Rock & Dirt     OR      Active
# 1   Surface       502030      Allied Dirt Moving Company     CO   Abandoned
# 2   Surface      4801789  AM Dirtworks & Aggregate Sales     ND   Abandoned
# 3  Facility      4201449        Atlas-Dirty Devil Mining     UT   Abandoned
# 4   Surface      4201450        Atlas-Dirty Devil Mining     UT   Abandoned
